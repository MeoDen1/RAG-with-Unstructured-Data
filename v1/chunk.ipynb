# %%
# %pip install PyMuPDF
# Out:
# Collecting PyMuPDF
#   Downloading PyMuPDF-1.24.9-cp310-none-manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting PyMuPDFb==1.24.9 (from PyMuPDF)
#   Downloading PyMuPDFb-1.24.9-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.4 kB)
# Downloading PyMuPDF-1.24.9-cp310-none-manylinux2014_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 11.6 MB/s eta 0:00:0000:010:01
# Downloading PyMuPDFb-1.24.9-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (15.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 52.1 MB/s eta 0:00:0000:0100:01
# Installing collected packages: PyMuPDFb, PyMuPDF
# Successfully installed PyMuPDF-1.24.9 PyMuPDFb-1.24.9
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import os
import torch
import pymupdf

os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %% [markdown]
# ## Preprocess document

# %%
file_path = "/kaggle/input/rag-document/data/Computer Networks.pdf"

# %%
def clean_text(text: str):
    # filter = ''.join([chr(i) for i in range(1, 32)])
    # text = text.translate(str.maketrans('', '', filter)).strip()
    text = text.replace('-\n', '')
    text = text.replace('\n', ' ')
    text = text.replace(u'\xa0', u' ')

    while text.find('  ') != -1:
        text = text.replace('  ', ' ') 

    return text

def load_document(file_path: str, chunk_size=32):
    """
    Loads pdf from `file_path` and generate list of chunks from the file
    """
    doc = pymupdf.open(file_path)
    output = []

    chunk_id = 0
    for i, page in enumerate(doc):
        # Get text per page
        text = page.get_text()

        # Clean text
        text = clean_text(text)

        words = text.split(' ')
        for j in range(0, len(words) - chunk_size + 1, 2):
            chunk = ' '.join(words[j:j + chunk_size])

            output.append({
                'chunk_id': chunk_id,
                'page': i,
                'text': chunk,
            })

            chunk_id += 1
    
    return output

chunks = load_document(file_path)
chunks[:5]
# Out:
# [{'chunk_id': 0,
#   'page': 4,
#   'text': 'COMPUTER NETWORKS FIFTH EDITION ANDREW S. TANENBAUM Vrije Universiteit Amsterdam, The Netherlands DAVID J. WETHERALL University of Washington Seattle, WA PRENTICE HALL Boston Columbus Indianapolis New York San Francisco Upper Saddle River'},
#  {'chunk_id': 1,
#   'page': 4,
#   'text': 'FIFTH EDITION ANDREW S. TANENBAUM Vrije Universiteit Amsterdam, The Netherlands DAVID J. WETHERALL University of Washington Seattle, WA PRENTICE HALL Boston Columbus Indianapolis New York San Francisco Upper Saddle River Amsterdam Cape'},
#  {'chunk_id': 2,
#   'page': 4,
#   'text': 'ANDREW S. TANENBAUM Vrije Universiteit Amsterdam, The Netherlands DAVID J. WETHERALL University of Washington Seattle, WA PRENTICE HALL Boston Columbus Indianapolis New York San Francisco Upper Saddle River Amsterdam Cape Town Dubai'},
#  {'chunk_id': 3,
#   'page': 4,
#   'text': 'TANENBAUM Vrije Universiteit Amsterdam, The Netherlands DAVID J. WETHERALL University of Washington Seattle, WA PRENTICE HALL Boston Columbus Indianapolis New York San Francisco Upper Saddle River Amsterdam Cape Town Dubai London Madrid'},
#  {'chunk_id': 4,
#   'page': 4,
#   'text': 'Universiteit Amsterdam, The Netherlands DAVID J. WETHERALL University of Washington Seattle, WA PRENTICE HALL Boston Columbus Indianapolis New York San Francisco Upper Saddle River Amsterdam Cape Town Dubai London Madrid Milan Paris'}]

# %%
df = pd.DataFrame(chunks)
df.head()
# Out:
#         chunk_id  page                                               text  \
# 0              0     4  COMPUTER NETWORKS FIFTH EDITION ANDREW S. TANE...
# 1              1     4  FIFTH EDITION ANDREW S. TANENBAUM Vrije Univer...
# 2              2     4  ANDREW S. TANENBAUM Vrije Universiteit Amsterd...
# 3              3     4  TANENBAUM Vrije Universiteit Amsterdam, The Ne...
# 4              4     4  Universiteit Amsterdam, The Netherlands DAVID ...
# ...          ...   ...                                                ...
# 192777    192777   961  and MobiSys, and cofounded the ACM HotNets wor...
# 192778    192778   961  and cofounded the ACM HotNets workshops. He ha...
# 192779    192779   961  the ACM HotNets workshops. He has served on nu...
# 192780    192780   961  HotNets workshops. He has served on numerous p...
# 192781    192781   961  He has served on numerous program committees f...
#
#         num_words  num_char
# 0              32       238
# 1              32       235
# 2              32       232
# 3              32       236
# 4              32       232
# ...           ...       ...
# 192777         32       203
# 192778         32       201
# 192779         32       195
# 192780         32       196
# 192781         32       210
#
# [192782 rows x 5 columns]

# %%
from transformers import AutoTokenizer, AutoModel

RESET = True
# model_name = "bert-base-uncased"
model_name = "BAAI/bge-small-en-v1.5"

tokenizer = None
model = None

if os.path.isdir("model/tokenizer") and os.path.isdir("model/embedding") and not RESET:
    tokenizer = AutoTokenizer.from_pretrained("model/tokenizer")
    model = AutoModel.from_pretrained("model/embedding")
    
else:
    # Then init
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModel.from_pretrained(model_name)
    
    device = "cuda:0" if torch.cuda.is_available() else "cpu"
    model.to(device)

    tokenizer.save_pretrained("model/tokenizer")
    model.save_pretrained("model/embedding")


assert tokenizer is not None
assert model is not None
# Out:
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]

# %%
def compute_embedding(text: list[str] | str):
    inputs = tokenizer(text, return_tensors='pt', padding=True, truncation=True).to(device)

    with torch.no_grad():
        # reduce mean in sequence length axis
        output = model(**inputs).last_hidden_state.mean(dim=1)

    return output.tolist()
# Out:
# 384

# %%
# Computer embedding for each chunk

batch_size = 1000

total = []

df_values = df["text"].values
num_batch = len(df) // batch_size

for i in range(num_batch + 1):
    print(f"Embedding batch {i + 1}")
    total += compute_embedding(df_values[i * batch_size : min((i + 1) * batch_size, len(df))].tolist())

df["embedding"] = pd.Series(total)
df
# Out:
# Embedding batch 1
# Embedding batch 2
# Embedding batch 3
# Embedding batch 4
# Embedding batch 5
# Embedding batch 6
# Embedding batch 7
# Embedding batch 8
# Embedding batch 9
# Embedding batch 10
# Embedding batch 11
# Embedding batch 12
# Embedding batch 13
# Embedding batch 14
# Embedding batch 15
# Embedding batch 16
# Embedding batch 17
# Embedding batch 18
# Embedding batch 19
# Embedding batch 20
# Embedding batch 21
# Embedding batch 22
# Embedding batch 23
# Embedding batch 24
# Embedding batch 25
# Embedding batch 26
# Embedding batch 27
# Embedding batch 28
# Embedding batch 29
# Embedding batch 30
# Embedding batch 31
# Embedding batch 32
# Embedding batch 33
# Embedding batch 34
# Embedding batch 35
# Embedding batch 36
# Embedding batch 37
# Embedding batch 38
# Embedding batch 39
# Embedding batch 40
# Embedding batch 41
# Embedding batch 42
# Embedding batch 43
# Embedding batch 44
# Embedding batch 45
# Embedding batch 46
# Embedding batch 47
# Embedding batch 48
# Embedding batch 49
# Embedding batch 50
# Embedding batch 51
# Embedding batch 52
# Embedding batch 53
# Embedding batch 54
# Embedding batch 55
# Embedding batch 56
# Embedding batch 57
# Embedding batch 58
# Embedding batch 59
# Embedding batch 60
# Embedding batch 61
# Embedding batch 62
# Embedding batch 63
# Embedding batch 64
# Embedding batch 65
# Embedding batch 66
# Embedding batch 67
# Embedding batch 68
# Embedding batch 69
# Embedding batch 70
# Embedding batch 71
# Embedding batch 72
# Embedding batch 73
# Embedding batch 74
# Embedding batch 75
# Embedding batch 76
# Embedding batch 77
# Embedding batch 78
# Embedding batch 79
# Embedding batch 80
# Embedding batch 81
# Embedding batch 82
# Embedding batch 83
# Embedding batch 84
# Embedding batch 85
# Embedding batch 86
# Embedding batch 87
# Embedding batch 88
# Embedding batch 89
# Embedding batch 90
# Embedding batch 91
# Embedding batch 92
# Embedding batch 93
# Embedding batch 94
# Embedding batch 95
# Embedding batch 96
# Embedding batch 97
# Embedding batch 98
# Embedding batch 99
# Embedding batch 100
# Embedding batch 101
# Embedding batch 102
# Embedding batch 103
# Embedding batch 104
# Embedding batch 105
# Embedding batch 106
# Embedding batch 107
# Embedding batch 108
# Embedding batch 109
# Embedding batch 110
# Embedding batch 111
# Embedding batch 112
# Embedding batch 113
# Embedding batch 114
# Embedding batch 115
# Embedding batch 116
# Embedding batch 117
# Embedding batch 118
# Embedding batch 119
# Embedding batch 120
# Embedding batch 121
# Embedding batch 122
# Embedding batch 123
# Embedding batch 124
# Embedding batch 125
# Embedding batch 126
# Embedding batch 127
# Embedding batch 128
# Embedding batch 129
# Embedding batch 130
# Embedding batch 131
# Embedding batch 132
# Embedding batch 133
# Embedding batch 134
# Embedding batch 135
# Embedding batch 136
# Embedding batch 137
# Embedding batch 138
# Embedding batch 139
# Embedding batch 140
# Embedding batch 141
# Embedding batch 142
# Embedding batch 143
# Embedding batch 144
# Embedding batch 145
# Embedding batch 146
# Embedding batch 147
# Embedding batch 148
# Embedding batch 149
# Embedding batch 150
# Embedding batch 151
# Embedding batch 152
# Embedding batch 153
# Embedding batch 154
# Embedding batch 155
# Embedding batch 156
# Embedding batch 157
# Embedding batch 158
# Embedding batch 159
# Embedding batch 160
# Embedding batch 161
# Embedding batch 162
# Embedding batch 163
# Embedding batch 164
# Embedding batch 165
# Embedding batch 166
# Embedding batch 167
# Embedding batch 168
# Embedding batch 169
# Embedding batch 170
# Embedding batch 171
# Embedding batch 172
# Embedding batch 173
# Embedding batch 174
# Embedding batch 175
# Embedding batch 176
# Embedding batch 177
# Embedding batch 178
# Embedding batch 179
# Embedding batch 180
# Embedding batch 181
# Embedding batch 182
# Embedding batch 183
# Embedding batch 184
# Embedding batch 185
# Embedding batch 186
# Embedding batch 187
# Embedding batch 188
# Embedding batch 189
# Embedding batch 190
# Embedding batch 191
# Embedding batch 192
# Embedding batch 193
#         chunk_id  page                                               text  \
# 0              0     4  COMPUTER NETWORKS FIFTH EDITION ANDREW S. TANE...
# 1              1     4  FIFTH EDITION ANDREW S. TANENBAUM Vrije Univer...
# 2              2     4  ANDREW S. TANENBAUM Vrije Universiteit Amsterd...
# 3              3     4  TANENBAUM Vrije Universiteit Amsterdam, The Ne...
# 4              4     4  Universiteit Amsterdam, The Netherlands DAVID ...
# ...          ...   ...                                                ...
# 192777    192777   961  and MobiSys, and cofounded the ACM HotNets wor...
# 192778    192778   961  and cofounded the ACM HotNets workshops. He ha...
# 192779    192779   961  the ACM HotNets workshops. He has served on nu...
# 192780    192780   961  HotNets workshops. He has served on numerous p...
# 192781    192781   961  He has served on numerous program committees f...
#
#         num_words  num_char                                          embedding
# 0              32       238  [-0.24107325077056885, -0.11326102167367935, 0...
# 1              32       235  [0.0692388117313385, 0.11854249238967896, 0.69...
# 2              32       232  [0.4598182439804077, 0.353718101978302, 0.3641...
# 3              32       236  [0.3230662941932678, 0.3634697198867798, 0.205...
# 4              32       232  [0.2969452142715454, 0.027495326474308968, 0.2...
# ...           ...       ...                                                ...
# 192777         32       203  [-0.18572883307933807, 0.10274776816368103, 0....
# 192778         32       201  [0.012503870762884617, -0.022333532571792603, ...
# 192779         32       195  [-0.14394520223140717, -0.11508528143167496, 0...
# 192780         32       196  [-0.2275371253490448, -0.16411814093589783, 0....
# 192781         32       210  [-0.46264907717704773, -0.060983508825302124, ...
#
# [192782 rows x 6 columns]

# %%
# Save data
df[['chunk_id', 'page', 'text', 'embedding']].to_csv('Computer Networks.csv', index=False)
